# %% [markdown]
# <a href="https://colab.research.google.com/github/vivekverm/Anonymous/blob/main/Arithmetic_logical_op.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
import math

# %%
img=cv2.imread("/content/half black and white.jpg")

# %%
img1=cv2.imread("/content/white circle.png")

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=546x316 at 0x7FCE6E959D90>

# %%
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7FCE6E896580>

# %%
img.shape
# Out:
# (316, 546, 3)

# %%
img1.shape
# Out:
# (168, 300, 3)

# %%
img2=cv2.resize(img1,(316,546))

# %%
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=316x546 at 0x7FCE6E81E040>

# %%
img2=cv2.resize(img1,(546,316))

# %%
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=546x316 at 0x7FCE6E7A40D0>

# %%
cv2.add(img,img2)
# Out:
# array([[[196, 196, 196],
#         [196, 196, 196],
#         [197, 197, 197],
#         ...,
#         [ 49,  49,  49],
#         [ 49,  49,  49],
#         [ 49,  49,  49]],
#
#        [[196, 196, 196],
#         [196, 196, 196],
#         [197, 197, 197],
#         ...,
#         [ 49,  49,  49],
#         [ 49,  49,  49],
#         [ 49,  49,  49]],
#
#        [[196, 196, 196],
#         [196, 196, 196],
#         [196, 196, 196],
#         ...,
#         [ 48,  48,  48],
#         [ 49,  49,  49],
#         [ 49,  49,  49]],
#
#        ...,
#
#        [[244, 244, 244],
#         [244, 244, 244],
#         [243, 243, 243],
#         ...,
#         [ 53,  53,  53],
#         [ 54,  54,  54],
#         [ 54,  54,  54]],
#
#        [[244, 244, 244],
#         [244, 244, 244],
#         [244, 244, 244],
#         ...,
#         [ 54,  54,  54],
#         [ 54,  54,  54],
#         [ 54,  54,  54]],
#
#        [[244, 244, 244],
#         [244, 244, 244],
#         [244, 244, 244],
# ...

# %%
Add=cv2.add(img,img2)

# %%
cv2_imshow(Add)
# Out:
# <PIL.Image.Image image mode=RGB size=546x316 at 0x7FCE6E7AD3D0>

# %%
Sub=cv2.subtract(img,img2)

# %%
cv2_imshow(Sub)
# Out:
# <PIL.Image.Image image mode=RGB size=546x316 at 0x7FCE6E88E3D0>

# %%
Mul=cv2.multiply(img,img2)

# %%
cv2_imshow(Mul)
# Out:
# <PIL.Image.Image image mode=RGB size=546x316 at 0x7FCE6E959E20>

# %%
OR=cv2.bitwise_or(img,img2)

# %%
cv2_imshow(OR)
# Out:
# <PIL.Image.Image image mode=RGB size=546x316 at 0x7FCE6E8968B0>

# %%
And=cv2.bitwise_and(img,img2)

# %%
cv2_imshow(And)
# Out:
# <PIL.Image.Image image mode=RGB size=546x316 at 0x7FCE7E422B20>

# %%
Xor=cv2.bitwise_xor(img,img2)

# %%
cv2_imshow(Xor)
# Out:
# <PIL.Image.Image image mode=RGB size=546x316 at 0x7FCE6E8969A0>
