# %% [markdown]
# <a href="https://colab.research.google.com/github/vivekverm/Anonymous/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
from google.colab.patches import cv2_imshow

# %%
img=cv2.imread("/content/download.png")

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=259x195 at 0x7F044198FBB0>

# %%
img1=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=L size=259x195 at 0x7F0430CFFC70>

# %%
img2=cv2.cvtColor(img,cv2.COLOR_RGB2YCR_CB)

# %%
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=259x195 at 0x7F04318BED60>

# %%
img.shape
# Out:
# (195, 259, 3)

# %%
img1.shape
# Out:
# (195, 259)

# %%
img2.shape
# Out:
# (195, 259, 3)

# %%
img.size
# Out:
# 151515

# %%
img1.size
# Out:
# 50505

# %%
img1[1:10,20:40]
# Out:
# array([[247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247,
#         247, 247, 247, 247, 247, 247, 247],
#        [247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247,
#         247, 247, 247, 247, 247, 247, 247],
#        [247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247,
#         247, 247, 247, 247, 247, 247, 247],
#        [247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247,
#         247, 247, 247, 247, 247, 247, 247],
#        [247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247,
#         247, 247, 247, 247, 247, 247, 247],
#        [247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247,
#         247, 247, 247, 247, 247, 247, 247],
#        [247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247,
#         247, 247, 247, 247, 247, 247, 247],
#        [247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247, 247,
#         247, 247, 247, 247, 247, 247, 247],
# ...

# %%
img1[10:10,20:40]
# Out:
# array([], shape=(0, 20), dtype=uint8)

# %%
A=cv2.resize(img,(100,100))

# %%
cv2_imshow(A)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7F0428996820>

# %%
image=cv2.imread("/content/CARS-TO-LAUNCH-IN-DIWALI.jpg")

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1600x900 at 0x7F0428A38100>

# %%
image.shape
# Out:
# (900, 1600, 3)

# %%
image.size
# Out:
# 4320000

# %%
B=cv2.resize(image,(500,500))

# %%
image1=cv2.imread("/content/2018-rolls-royce-phantom-1536152159.png")

# %%
image1.shape
# Out:
# (645, 1290, 3)

# %%
image1.size
# Out:
# 2496150

# %%
C=cv2.resize(image1,(500,500))

# %%
cv2_imshow(B)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F0428967F10>

# %%
cv2_imshow(C)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F04289673D0>
